# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # My First Markdown Cell in Jupyter Notebook
#
# This notebook was created for the ITAI 1378 Colab and GitHub practice lab.

# %% [markdown]
# # My First Jupyter Notebook
#
# ## My Reflection
#
# In this activity, I learned how to use Jupyter Notebook and create both Markdown and Code cells. I used a Python command to print "Hello, World!" and observed the output. This exercise helped me understand that Markdown cells are used for explanations, while Code cells are used to run programs. I also learned how to save and upload a notebook to GitHub.
